# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data_population = np.loadtxt('pop.txt', delimiter = ',')
data_year = np.loadtxt('year.txt', delimiter = ',')
print(data_population)
print(data_year)
# Out:
# [ 2.53  2.57  2.62  2.67  2.71  2.76  2.81  2.86  2.92  2.97  3.03  3.08
#   3.14  3.2   3.26  3.33  3.4   3.47  3.54  3.62  3.69  3.77  3.84  3.92
#   4.    4.07  4.15  4.22  4.3   4.37  4.45  4.53  4.61  4.69  4.78  4.86
#   4.95  5.05  5.14  5.23  5.32  5.41  5.49  5.58  5.66  5.74  5.82  5.9
#   5.98  6.05  6.13  6.2   6.28  6.36  6.44  6.51  6.59  6.67  6.75  6.83
#   6.92  7.    7.08  7.16  7.24  7.32  7.4   7.48  7.56  7.64  7.72  7.79
#   7.87  7.94  8.01  8.08  8.15  8.22  8.29  8.36  8.42  8.49  8.56  8.62
#   8.68  8.74  8.8   8.86  8.92  8.98  9.04  9.09  9.15  9.2   9.26  9.31
#   9.36  9.41  9.46  9.5   9.55  9.6   9.64  9.68  9.73  9.77  9.81  9.85
#   9.88  9.92  9.96  9.99 10.03 10.06 10.09 10.13 10.16 10.19 10.22 10.25
#  10.28 10.31 10.33 10.36 10.38 10.41 10.43 10.46 10.48 10.5  10.52 10.55
#  10.57 10.59 10.61 10.63 10.65 10.66 10.68 10.7  10.72 10.73 10.75 10.77
#  10.78 10.79 10.81 10.82 10.83 10.84 10.85]
# ...

# %%
pop = np.c_[data_population]
year = np.c_[data_year]
plt.plot(year,pop)
plt.show()

# %%
data_gdp_cap = np.loadtxt('gdp_cap.txt', delimiter = ',')
data_life_exp = np.loadtxt('life_exp.txt' delimiter = ',')
gdp_cap = np.c_[data_gdp_cap]
life_exp = np.c_[data_life_exp]
plt.plot(gdp_cap, life_exp)
plt.show()
# Out:
#   File "<ipython-input-3-5e46928bae1c>", line 2
#     data_life_exp = np.loadtxt('life_exp.txt' delimiter = ',')
#                                                       ^
# SyntaxError: invalid syntax

# %%
data_gdp_cap = np.loadtxt('gdp_cap.txt', delimiter = ',')
data_life_exp = np.loadtxt('life_exp.txt', delimiter = ',')
gdp_cap = np.c_[data_gdp_cap]
life_exp = np.c_[data_life_exp]
plt.plot(gdp_cap, life_exp)
plt.show()

# %%
#the line plot is  very scattered and not arranged

# %%
plt.scatter(gdp_cap,life_exp)
plt.xscale('log')
plt.show()

# %%
# There is hardly any correlation between the variables

# %%
data = np.loadtxt('pop2.txt', delimiter = ',')
pop_2 = np.c_[data]
plt.scatter(pop_2, life_exp)
plt.xscale('log')
plt.show()

# %%
plt.hist(life_exp)
plt.show()

# %%
plt.hist(life_exp,bins = '5')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-6802acc652a1> in <module>
# ----> 1 plt.hist(life_exp,bins = '5')
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2659         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2660         color=color, label=label, stacked=stacked, normed=normed,
# -> 2661         **({"data": data} if data is not None else {}), **kwargs)
#    2662
#    2663
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# ...

# %%
plt.hist(life_exp, bins  = 5)
plt.show()

# %%
plt.clf()

# %%
plt.hist(life_exp, bins= 20)
plt.show()
plt.clf()

# %%
data_1950 =np.loadtxt('life_exp1950.txt', delimiter= ',')
life_exp1950 = np.c_[data_1950]
plt.hist(life_exp1950, bins = 15)
plt.show()
plt.clf()

# %%
plt.hist(life_exp, bins = 15)
plt.show()
plt.clf()

# %%
plt.scatter(gdp_cap, life_exp, edgecolor = 'black')
plt.xscale('log')
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
plt.show()

# %%
plt.scatter(life_exp, gdp_cap, edgecolor = 'black')
plt.xscale('log')
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
plt.show()

# %%
plt.scatter(gdp_cap, life_exp, edgecolor = 'black')
plt.xscale('log')
xlab = 'GDP per Capita [in USD]'
ylab = 'Life Expectancy [in years]'
title = 'World Development in 2007'
plt.xlabel(xlab)
plt.ylabel(ylab)
plt.title(title)
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']
plt.xticks(tick_val,tick_lab)
plt.show()

# %%
data = np.loadtxt('pop3.txt', delimiter = ',')
np_pop = np.array(data)
np_pop = np_pop*2

# %%
print(np_pop)
# Out:
# [6.37798460e+01 7.20104600e+00 6.66664320e+01 2.48409520e+01
#  8.06038540e+01 4.08683520e+01 1.63995660e+01 1.41714600e+00
#  3.00896678e+02 2.07844520e+01 1.61566280e+01 1.82383040e+01
#  9.10439600e+00 3.27826200e+00 3.80021294e+02 1.46457160e+01
#  2.86524060e+01 1.67810100e+01 2.82637160e+01 3.53925860e+01
#  6.67802820e+01 8.73807600e+00 2.04776140e+01 3.25694820e+01
#  2.63736619e+03 8.84551000e+01 1.42192000e+00 1.29213518e+02
#  7.60122000e+00 8.26776800e+00 3.60268180e+01 8.98662400e+00
#  2.28339740e+01 2.04574880e+01 1.09362400e+01 9.92748000e-01
#  1.86392440e+01 2.75113600e+01 1.60529086e+02 1.38793760e+01
#  1.10240200e+00 9.81317000e+00 1.53023774e+02 1.04769200e+01
#  1.22167832e+02 2.90973400e+00 3.37671800e+00 1.64801992e+02
#  4.57466760e+01 2.14125800e+01 2.51458560e+01 1.98956280e+01
#  2.94408200e+00 1.70056280e+01 1.49675260e+01 1.39608240e+01
#  1.99122160e+01 6.03862000e-01 2.22079266e+03 4.47094000e+02
# ...

# %%
plt.scatter(gdp_cap, life_exp, s = np_pop, edgecolor = 'black', linewidth = 1.2)

plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks(tick_val,tick_lab)
plt.show()

# %%
import importlib; importlib.reload(plt)
plt.clf()
import pandas as pd
df = pd.read_csv('gapminder.csv', index_col = 0)
gdp_cap = list(df.gdp_cap)
life_exp = list(df.life_exp)
pop = list(df['population']/1e6)
cont = list(df.cont)
dict = { 
        'Asia':'red',
        'Europe':'green',
        'Africa':'blue',
        'Americas':'yellow',
        'Oceania':'black'
}
col = [dict[x] for x in cont]
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = col, alpha = 0.8, edgecolor = 'black', linewidth = 1.2)
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks(tick_val, tick_lab)
plt.show()

# %%
print(df.gdp_cap)
# Out:
# 11        974.580338
# 23       5937.029526
# 35       6223.367465
# 47       4797.231267
# 59      12779.379640
# 71      34435.367440
# 83      36126.492700
# 95      29796.048340
# 107      1391.253792
# 119     33692.605080
# 131      1441.284873
# 143      3822.137084
# 155      7446.298803
# 167     12569.851770
# 179      9065.800825
# 191     10680.792820
# 203      1217.032994
# 215       430.070692
# 227      1713.778686
# 239      2042.095240
# 251     36319.235010
# 263       706.016537
# 275      1704.063724
# 287     13171.638850
# 299      4959.114854
# 311      7006.580419
# 323       986.147879
# 335       277.551859
# 347      3632.557798
# 359      9645.061420
#             ...
# 1355      862.540756
# 1367    47143.179640
# 1379    18678.314350
# 1391    25768.257590
# 1403      926.141068
# 1415     9269.657808
# 1427    28821.063700
# 1439     3970.095407
# 1451     2602.394995
# 1463     4513.480643
# 1475    33859.748350
# 1487    37506.419070
# ...

# %%
print(list(df.gdp_cap))
# Out:
# [974.5803384, 5937.029525999998, 6223.367465, 4797.231267, 12779.37964, 34435.367439999995, 36126.4927, 29796.04834, 1391.253792, 33692.60508, 1441.284873, 3822.137084, 7446.298803, 12569.85177, 9065.800825, 10680.79282, 1217.032994, 430.0706916, 1713.778686, 2042.09524, 36319.23501, 706.016537, 1704.063724, 13171.63885, 4959.114854, 7006.580419, 986.1478792, 277.5518587, 3632.557798, 9645.06142, 1544.750112, 14619.222719999998, 8948.102923, 22833.30851, 35278.41874, 2082.4815670000007, 6025.3747520000015, 6873.262326000001, 5581.180998, 5728.353514, 12154.08975, 641.3695236000002, 690.8055759, 33207.0844, 30470.0167, 13206.48452, 752.7497265, 32170.37442, 1327.60891, 27538.41188, 5186.050003, 942.6542111, 579.2317429999998, 1201.637154, 3548.3308460000007, 39724.97867, 18008.94444, 36180.78919, 2452.210407, 3540.651564, 11605.71449, 4471.061906, 40675.99635, 25523.2771, 28569.7197, 7320.8802620000015, 31656.06806, 4519.461171, 1463.249282, 1593.06548, 23348.139730000006, 47306.98978
# ...

# %%
print(df['population'])
# Out:
# 11      3.188992e+07
# 23      3.600523e+06
# 35      3.333322e+07
# 47      1.242048e+07
# 59      4.030193e+07
# 71      2.043418e+07
# 83      8.199783e+06
# 95      7.085730e+05
# 107     1.504483e+08
# 119     1.039223e+07
# 131     8.078314e+06
# 143     9.119152e+06
# 155     4.552198e+06
# 167     1.639131e+06
# 179     1.900106e+08
# 191     7.322858e+06
# 203     1.432620e+07
# 215     8.390505e+06
# 227     1.413186e+07
# 239     1.769629e+07
# 251     3.339014e+07
# 263     4.369038e+06
# 275     1.023881e+07
# 287     1.628474e+07
# 299     1.318683e+09
# 311     4.422755e+07
# 323     7.109600e+05
# 335     6.460676e+07
# 347     3.800610e+06
# 359     4.133884e+06
#             ...
# 1355    6.144562e+06
# 1367    4.553009e+06
# 1379    5.447502e+06
# 1391    2.009245e+06
# 1403    9.118773e+06
# 1415    4.399783e+07
# 1427    4.044819e+07
# 1439    2.037824e+07
# 1451    4.229293e+07
# 1463    1.133066e+06
# 1475    9.031088e+06
# 1487    7.554661e+06
# ...

# %%
print(df)
# Out:
#                        country  year    population      cont  life_exp  \
# 11                 Afghanistan  2007  3.188992e+07      Asia    43.828
# 23                     Albania  2007  3.600523e+06    Europe    76.423
# 35                     Algeria  2007  3.333322e+07    Africa    72.301
# 47                      Angola  2007  1.242048e+07    Africa    42.731
# 59                   Argentina  2007  4.030193e+07  Americas    75.320
# 71                   Australia  2007  2.043418e+07   Oceania    81.235
# 83                     Austria  2007  8.199783e+06    Europe    79.829
# 95                     Bahrain  2007  7.085730e+05      Asia    75.635
# 107                 Bangladesh  2007  1.504483e+08      Asia    64.062
# 119                    Belgium  2007  1.039223e+07    Europe    79.441
# 131                      Benin  2007  8.078314e+06    Africa    56.728
# 143                    Bolivia  2007  9.119152e+06  Americas    65.554
# ...

# %%
plt.scatter(x = gdp_cap, y = life_exp, s = np_pop, c = col, alpha = 0.8, edgecolor = 'black', linewidth = 1.2)
plt.xscale('log') 
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')
plt.xticks([1000,10000,100000], ['1k','10k','100k'])
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')
plt.grid(True)
plt.show()
